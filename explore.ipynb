# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('P2M3_nur_alamsyah_data_raw.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   row_index                       84548 non-null  object
#  1   BOROUGH                         67830 non-null  float64
#  2   NEIGHBORHOOD                    67830 non-null  object
#  3   BUILDING CLASS CATEGORY         67830 non-null  object
#  4   TAX CLASS AT PRESENT            67830 non-null  object
#  5   BLOCK                           67830 non-null  float64
#  6   LOT                             67830 non-null  float64
#  7   EASE-MENT                       67830 non-null  object
#  8   BUILDING CLASS AT PRESENT       67830 non-null  object
#  9   ADDRESS                         67830 non-null  object
#  10  APARTMENT NUMBER                67830 non-null  object
#  11  ZIP CODE                        67830 non-null  float64
#  12  RESIDENTIAL UNITS               67830 non-null  float64
#  13  COMMERCIAL UNITS                67830 non-null  float64
#  14  TOTAL UNITS                     67830 non-null  float64
#  15  LAND SQUARE FEET                67830 non-null  object
#  16  GROSS SQUARE FEET               67830 non-null  object
#  17  YEAR BUILT                      67830 non-null  float64
#  18  TAX CLASS AT TIME OF SALE       67830 non-null  float64
#  19  BUILDING CLASS AT TIME OF SALE  67830 non-null  object
#  20  SALE PRICE                      67830 non-null  object
#  21  SALE DATE                       67830 non-null  object
# dtypes: float64(9), object(13)
# memory usage: 14.2+ MB

# %%
# Replace '-' with NaN in 'SALE PRICE' column
df['SALE PRICE'].replace(' -  ', np.nan, inplace=True)

# %%
for col in df.columns:
    df[col].replace(' -  ', np.nan, inplace=True)

# %%
df['SALE DATE'] = pd.to_datetime(df['SALE DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   row_index                       84548 non-null  object
#  1   BOROUGH                         67830 non-null  float64
#  2   NEIGHBORHOOD                    67830 non-null  object
#  3   BUILDING CLASS CATEGORY         67830 non-null  object
#  4   TAX CLASS AT PRESENT            67830 non-null  object
#  5   BLOCK                           67830 non-null  float64
#  6   LOT                             67830 non-null  float64
#  7   EASE-MENT                       67830 non-null  object
#  8   BUILDING CLASS AT PRESENT       67830 non-null  object
#  9   ADDRESS                         67830 non-null  object
#  10  APARTMENT NUMBER                67830 non-null  object
#  11  ZIP CODE                        67830 non-null  float64
#  12  RESIDENTIAL UNITS               67830 non-null  float64
#  13  COMMERCIAL UNITS                67830 non-null  float64
#  14  TOTAL UNITS                     67830 non-null  float64
#  15  LAND SQUARE FEET                54544 non-null  object
#  16  GROSS SQUARE FEET               53186 non-null  object
#  17  YEAR BUILT                      67830 non-null  float64
#  18  TAX CLASS AT TIME OF SALE       67830 non-null  float64
#  19  BUILDING CLASS AT TIME OF SALE  67830 non-null  object
#  20  SALE PRICE                      54582 non-null  object
#  21  SALE DATE                       67830 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(9), object(12)
# memory usage: 14.2+ MB

# %%
df.head(5)
# Out:
#   row_index  BOROUGH   NEIGHBORHOOD  \
# 0         4      1.0  ALPHABET CITY
# 1         5      1.0  ALPHABET CITY
# 2         6      1.0  ALPHABET CITY
# 3         7      1.0  ALPHABET CITY
# 4         8      1.0  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A  392.0
# 1  07 RENTALS - WALKUP APARTMENTS                                 2  399.0
# 2  07 RENTALS - WALKUP APARTMENTS                                 2  399.0
# 3  07 RENTALS - WALKUP APARTMENTS                                2B  402.0
# 4  07 RENTALS - WALKUP APARTMENTS                                2A  404.0
#
#     LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0   6.0                                  C2            153 AVENUE B  ...
# 1  26.0                                  C7   234 EAST 4TH   STREET  ...
# 2  39.0                                  C7   197 EAST 3RD   STREET  ...
# 3  21.0                                  C4     154 EAST 7TH STREET  ...
# 4  55.0                                  C2  301 EAST 10TH   STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0               5.0               0.0          5.0              1633
# 1              28.0               3.0         31.0              4616
# 2              16.0               1.0         17.0              2212
# 3              10.0               0.0         10.0              2272
# 4               6.0               0.0          6.0              2369
#
#    GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               6440     1900.0                       2.0
# 1              18690     1900.0                       2.0
# 2               7803     1900.0                       2.0
# 3               6794     1913.0                       2.0
# 4               4615     1900.0                       2.0
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE  SALE DATE
# 0                              C2     6625000 2017-07-19
# 1                              C7         NaN 2016-12-14
# 2                              C7         NaN 2016-12-09
# 3                              C4     3936272 2016-09-23
# 4                              C2     8000000 2016-11-17
#
# [5 rows x 22 columns]

# %%
df['SALE DATE'].min()
# Out:
# Timestamp('2016-09-01 00:00:00')

# %%
df['SALE DATE'].max()
# Out:
# Timestamp('2017-08-31 00:00:00')

# %%
df.isnull().sum()
# Out:
# row_index                             0
# BOROUGH                           16718
# NEIGHBORHOOD                      16718
# BUILDING CLASS CATEGORY           16718
# TAX CLASS AT PRESENT              16718
# BLOCK                             16718
# LOT                               16718
# EASE-MENT                         16718
# BUILDING CLASS AT PRESENT         16718
# ADDRESS                           16718
# APARTMENT NUMBER                  16718
# ZIP CODE                          16718
# RESIDENTIAL UNITS                 16718
# COMMERCIAL UNITS                  16718
# TOTAL UNITS                       16718
# LAND SQUARE FEET                  30004
# GROSS SQUARE FEET                 31362
# YEAR BUILT                        16718
# TAX CLASS AT TIME OF SALE         16718
# BUILDING CLASS AT TIME OF SALE    16718
# SALE PRICE                        29966
# SALE DATE                         16718
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# row_index                             0
# BOROUGH                           16718
# NEIGHBORHOOD                      16718
# BUILDING CLASS CATEGORY           16718
# TAX CLASS AT PRESENT              16718
# BLOCK                             16718
# LOT                               16718
# EASE-MENT                         16718
# BUILDING CLASS AT PRESENT         16718
# ADDRESS                           16718
# APARTMENT NUMBER                  16718
# ZIP CODE                          16718
# RESIDENTIAL UNITS                 16718
# COMMERCIAL UNITS                  16718
# TOTAL UNITS                       16718
# LAND SQUARE FEET                  30004
# GROSS SQUARE FEET                 31362
# YEAR BUILT                        16718
# TAX CLASS AT TIME OF SALE         16718
# BUILDING CLASS AT TIME OF SALE    16718
# SALE PRICE                        29966
# SALE DATE                         16718
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df['SALE PRICE'] = df['SALE PRICE'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44495 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   row_index                       44495 non-null  object
#  1   BOROUGH                         44495 non-null  float64
#  2   NEIGHBORHOOD                    44495 non-null  object
#  3   BUILDING CLASS CATEGORY         44495 non-null  object
#  4   TAX CLASS AT PRESENT            44495 non-null  object
#  5   BLOCK                           44495 non-null  float64
#  6   LOT                             44495 non-null  float64
#  7   EASE-MENT                       44495 non-null  object
#  8   BUILDING CLASS AT PRESENT       44495 non-null  object
#  9   ADDRESS                         44495 non-null  object
#  10  APARTMENT NUMBER                44495 non-null  object
#  11  ZIP CODE                        44495 non-null  float64
#  12  RESIDENTIAL UNITS               44495 non-null  float64
#  13  COMMERCIAL UNITS                44495 non-null  float64
#  14  TOTAL UNITS                     44495 non-null  float64
#  15  LAND SQUARE FEET                44495 non-null  object
#  16  GROSS SQUARE FEET               44495 non-null  object
#  17  YEAR BUILT                      44495 non-null  float64
#  18  TAX CLASS AT TIME OF SALE       44495 non-null  float64
#  19  BUILDING CLASS AT TIME OF SALE  44495 non-null  object
#  20  SALE PRICE                      44495 non-null  int64
#  21  SALE DATE                       44495 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(9), int64(1), object(11)
# memory usage: 7.8+ MB

# %%
df.to_csv('new.csv', index=False)

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20440\1718083031.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df.head()
# Out:
#   row_index  BOROUGH   NEIGHBORHOOD           BUILDING CLASS CATEGORY  \
# 0         4      1.0  ALPHABET CITY    07 RENTALS - WALKUP APARTMENTS
# 3         7      1.0  ALPHABET CITY    07 RENTALS - WALKUP APARTMENTS
# 4         8      1.0  ALPHABET CITY    07 RENTALS - WALKUP APARTMENTS
# 6        10      1.0  ALPHABET CITY    07 RENTALS - WALKUP APARTMENTS
# 9        13      1.0  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A  392.0    6.0                                  C2
# 3                   2B  402.0   21.0                                  C4
# 4                   2A  404.0   55.0                                  C2
# 6                   2B  406.0   32.0                                  C4
# 9                    2  387.0  153.0                                  D9
#
#                   ADDRESS  ... RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0            153 AVENUE B  ...               5.0               0.0
# 3     154 EAST 7TH STREET  ...              10.0               0.0
# 4  301 EAST 10TH   STREET  ...               6.0               0.0
# 6            210 AVENUE B  ...               8.0               0.0
# 9     629 EAST 5TH STREET  ...              24.0               0.0
#
#    TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET YEAR BUILT  \
# 0          5.0              1633               6440     1900.0
# 3         10.0              2272               6794     1913.0
# 4          6.0              2369               4615     1900.0
# 6          8.0              1750               4226     1920.0
# 9         24.0              4489              18523     1920.0
#
#   TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                       2.0                              C2     6625000
# 3                       2.0                              C4     3936272
# 4                       2.0                              C2     8000000
# 6                       2.0                              C4     3192840
# 9                       2.0                              D9    16232000
#
#    SALE DATE
# 0 2017-07-19
# 3 2016-09-23
# 4 2016-11-17
# 6 2016-09-23
# 9 2016-11-07
#
# [5 rows x 22 columns]

# %%
df.nunique()
# Out:
# row_index                         24425
# BOROUGH                               5
# NEIGHBORHOOD                        250
# BUILDING CLASS CATEGORY              47
# TAX CLASS AT PRESENT                 11
# BLOCK                             10477
# LOT                                1785
# EASE-MENT                             1
# BUILDING CLASS AT PRESENT           158
# ADDRESS                           38330
# APARTMENT NUMBER                   1559
# ZIP CODE                            180
# RESIDENTIAL UNITS                   157
# COMMERCIAL UNITS                     43
# TOTAL UNITS                         168
# LAND SQUARE FEET                   5173
# GROSS SQUARE FEET                  5090
# YEAR BUILT                          145
# TAX CLASS AT TIME OF SALE             4
# BUILDING CLASS AT TIME OF SALE      158
# SALE PRICE                         5908
# SALE DATE                           362
# dtype: int64

# %%
df['TAX CLASS AT TIME OF SALE'].unique()
# Out:
# array([2., 4., 1., 3.])

# %%
df['BUILDING CLASS CATEGORY'].unique()
# Out:
# array(['07 RENTALS - WALKUP APARTMENTS',
#        '08 RENTALS - ELEVATOR APARTMENTS', '09 COOPS - WALKUP APARTMENTS',
#        '14 RENTALS - 4-10 UNIT', '22 STORE BUILDINGS',
#        '01 ONE FAMILY DWELLINGS', '02 TWO FAMILY DWELLINGS',
#        '03 THREE FAMILY DWELLINGS', '21 OFFICE BUILDINGS',
#        '23 LOFT BUILDINGS', '25 LUXURY HOTELS', '26 OTHER HOTELS',
#        '37 RELIGIOUS FACILITIES', '38 ASYLUMS AND HOMES',
#        '29 COMMERCIAL GARAGES', '41 TAX CLASS 4 - OTHER', '30 WAREHOUSES',
#        '34 THEATRES', '27 FACTORIES',
#        '40 SELECTED GOVERNMENTAL FACILITIES',
#        '32 HOSPITAL AND HEALTH FACILITIES',
#        '10 COOPS - ELEVATOR APARTMENTS', '31 COMMERCIAL VACANT LAND',
#        '11A CONDO-RENTALS', '33 EDUCATIONAL FACILITIES',
#        '04 TAX CLASS 1 CONDOS', '05 TAX CLASS 1 VACANT LAND',
#        '06 TAX CLASS 1 - OTHER', '44 CONDO PARKING',
#        '12 CONDOS - WALKUP APARTMENTS', '13 CONDOS - ELEVATOR APARTMENTS',
#        '35 INDOOR PUBLIC AND CULTURAL FACILITIES',
#        '36 OUTDOOR RECREATIONAL FACILITIES', '43 CONDO OFFICE BUILDINGS',
#        '18 TAX CLASS 3 - UNTILITY PROPERTIES',
#        '47 CONDO NON-BUSINESS STORAGE', '46 CONDO STORE BUILDINGS',
#        '15 CONDOS - 2-10 UNIT RESIDENTIAL',
#        '16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT', '17 CONDO COOPS',
#        '28 COMMERCIAL CONDOS', '48 CONDO TERRACES/GARDENS/CABANAS',
#        '49 CONDO WAREHOUSES/FACTORY/INDUS',
#        '42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC', '45 CONDO HOTELS',
#        '11 SPECIAL CONDO BILLING LOTS', '39 TRANSPORTATION FACILITIES'],
#       dtype=object)

# %%
df['BOROUGH'].unique()
# Out:
# array([1., 2., 3., 4., 5.])

# %%
df[df['SALE PRICE']<10]
# Out:
#       row_index  BOROUGH     NEIGHBORHOOD  \
# 5609       5613      1.0   HARLEM-CENTRAL
# 5706       5710      1.0      HARLEM-EAST
# 5726       5730      1.0      HARLEM-EAST
# 6045       6049      1.0     HARLEM-UPPER
# 6195       6199      1.0           INWOOD
# ...         ...      ...              ...
# 80138      4004      5.0     NEW BRIGHTON
# 80881      4747      5.0  NEW SPRINGVILLE
# 83181      7047      5.0        TODT HILL
# 83182      7048      5.0        TODT HILL
# 83291      7157      5.0      TOTTENVILLE
#
#                    BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 5609   40 SELECTED GOVERNMENTAL FACILITIES                    4  1773.0
# 5706        07 RENTALS - WALKUP APARTMENTS                   2B  1643.0
# 5726        07 RENTALS - WALKUP APARTMENTS                    2  1666.0
# 6045      08 RENTALS - ELEVATOR APARTMENTS                    2  2064.0
# 6195      08 RENTALS - ELEVATOR APARTMENTS                    2  2238.0
# ...                                    ...                  ...     ...
# 80138              01 ONE FAMILY DWELLINGS                    1    66.0
# 80881              01 ONE FAMILY DWELLINGS                    1  2410.0
# 83181            33 EDUCATIONAL FACILITIES                    4   683.0
# 83182            33 EDUCATIONAL FACILITIES                    4   683.0
# 83291              01 ONE FAMILY DWELLINGS                    1  7863.0
#
#          LOT EASE-MENT BUILDING CLASS AT PRESENT                   ADDRESS  \
# 5609    62.0                                  Y1       120 EAST 125 STREET
# 5706    51.0                                  C7       152 EAST 116 STREET
# 5726    41.0                                  C4       212 EAST 117 STREET
# 6045    36.0                                  D1    795 ST NICHOLAS AVENUE
# 6195    33.0                                  D9             4857 BROADWAY
# ...      ...       ...                       ...                       ...
# 80138   58.0                                  A2  168 WEST BUCHANAN STREET
# 80881   11.0                                  A5    282 RICHMOND HILL ROAD
# 83181    1.0                                  W1         715 OCEAN TERRACE
# 83182  301.0                                  W1             MILFORD DRIVE
# 83291  232.0                                  A5            48 FOREST LANE
#
#        ... RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 5609   ...               0.0               1.0          1.0              2523
# 5706   ...               8.0               2.0         10.0              2523
# 5726   ...              14.0               0.0         14.0              4037
# 6045   ...              56.0               0.0         56.0              6700
# 6195   ...              28.0               1.0         29.0              7500
# ...    ...               ...               ...          ...               ...
# 80138  ...               1.0               0.0          1.0              5000
# 80881  ...               1.0               0.0          1.0              1110
# 83181  ...               0.0               1.0          1.0           2128899
# 83182  ...               0.0               1.0          1.0             78672
# 83291  ...               1.0               0.0          1.0               910
#
#        GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 5609                8500     1950.0                       4.0
# 5706                9750     1910.0                       2.0
# 5726               16989     1910.0                       2.0
# 6045               41800     1920.0                       2.0
# 6195               30122     2013.0                       2.0
# ...                  ...        ...                       ...
# 80138               1092     1950.0                       1.0
# 80881               1500     1987.0                       1.0
# 83181                240     1965.0                       4.0
# 83182             126468     1965.0                       4.0
# 83291               1060     1999.0                       1.0
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE  SALE DATE
# 5609                               Y1           1 2017-01-04
# 5706                               C7           1 2017-06-23
# 5726                               C4           1 2016-12-28
# 6045                               D1           1 2017-06-21
# 6195                               D9           1 2017-08-09
# ...                               ...         ...        ...
# 80138                              A2           1 2017-05-15
# 80881                              A5           1 2017-01-09
# 83181                              W1           1 2016-11-14
# 83182                              W1           1 2016-12-09
# 83291                              A5           1 2016-10-03
#
# [9974 rows x 22 columns]

# %%
df['RESIDENTIAL UNITS'].unique()
# Out:
# array([5.000e+00, 1.000e+01, 6.000e+00, 8.000e+00, 2.400e+01, 3.000e+00,
#        4.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 2.200e+01, 9.000e+00,
#        1.500e+01, 3.000e+01, 3.500e+01, 1.100e+01, 2.800e+01, 7.000e+00,
#        1.800e+01, 1.200e+01, 1.600e+01, 2.000e+01, 2.100e+01, 1.900e+01,
#        4.800e+01, 5.290e+02, 4.760e+02, 3.170e+02, 1.400e+01, 4.200e+01,
#        1.070e+02, 3.100e+01, 3.600e+01, 3.400e+01, 3.300e+01, 7.400e+01,
#        2.900e+01, 2.300e+01, 2.500e+01, 2.860e+02, 2.560e+02, 7.710e+02,
#        2.570e+02, 3.800e+01, 3.110e+02, 4.100e+01, 5.100e+01, 7.600e+01,
#        4.500e+01, 7.200e+01, 5.600e+01, 6.800e+01, 3.700e+01, 5.000e+01,
#        2.600e+01, 1.700e+01, 6.100e+01, 6.000e+01, 8.940e+02, 6.700e+01,
#        1.840e+02, 7.800e+01, 1.810e+02, 1.300e+01, 1.020e+02, 1.210e+02,
#        5.200e+01, 2.700e+01, 7.000e+01, 3.690e+02, 7.700e+01, 4.000e+01,
#        2.330e+02, 9.100e+01, 3.200e+01, 1.090e+02, 3.870e+02, 1.530e+02,
#        1.930e+02, 6.200e+01, 1.460e+02, 9.400e+01, 4.600e+01, 4.400e+01,
#        8.400e+01, 7.500e+01, 6.500e+01, 9.500e+01, 4.900e+01, 6.300e+01,
#        6.400e+01, 1.000e+02, 5.400e+01, 4.300e+01, 7.160e+02, 6.800e+02,
#        4.700e+01, 1.790e+02, 7.100e+01, 3.900e+01, 5.300e+01, 5.500e+01,
#        2.830e+02, 6.600e+01, 1.140e+02, 5.900e+01, 8.900e+01, 7.300e+01,
#        7.900e+01, 8.300e+01, 4.980e+02, 8.100e+01, 1.620e+02, 1.270e+02,
#        2.220e+02, 9.900e+01, 1.300e+02, 9.000e+01, 5.800e+01, 1.590e+02,
#        4.620e+02, 1.420e+02, 9.480e+02, 1.290e+02, 8.890e+02, 2.710e+02,
#        1.500e+02, 1.200e+02, 5.700e+01, 1.170e+02, 1.060e+02, 8.500e+01,
#        1.030e+02, 1.180e+02, 1.640e+02, 1.390e+02, 1.650e+02, 1.220e+02,
#        1.130e+02, 1.340e+02, 2.780e+02, 1.350e+02, 3.240e+02, 1.800e+02,
#        9.600e+01, 1.440e+02, 1.520e+02, 8.800e+01, 1.360e+02, 2.910e+02,
#        1.844e+03, 1.980e+02, 1.480e+02, 4.460e+02, 3.350e+02, 1.430e+02,
#        1.280e+02])
